# %% [markdown]
# <a href="https://colab.research.google.com/github/kunampurnachandrasekharreddy-droid/python-programs/blob/main/week4/Exercise4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
a="practice makes man perfect"
b=a.split()
print(b)
c=" ".join(b)
print(c)
# Out:
# ['practice', 'makes', 'man', 'perfect']
# practice makes man perfect

# %%
#strings in python
p=input()
q=str(input())
print(p+q)
print(p*3)
print(p[3])
print(p[2:5])
print(p[-1:-4])
for i in q:
  print(i)
# Out:
# python
# java class
# pythonjava class
# pythonpythonpython
# h
# tho
#
# j
# a
# v
# a
#
# c
# l
# a
# s
# s

# %%
#string methods
a=q.split()
print(a)
b=" ".join(a)
print(b)
print(q.upper())
print(q.count('a'))
print(q.find('j'))
print(q.replace("java","JAVA"))
print(len(q))
# Out:
# ['java', 'class']
# java class
# JAVA CLASS
# 3
# 0
# JAVA class
# 10

# %%
c=" python "
print(c.strip())
# Out:
# python

# %%
#prgram that counts no of vowels in string
a=input()
count=0
for i in a:
  if i=='a'or i=='A' or i=='e' or i=='E' or i=='O' or i=='o' or i=='i' or i=='I' or i=='u' or i=='U':
    count+=1
print(count)
# Out:
# python programming
# 4

# %%
#program that checks the sub string in the string
a=input("enter string:")
b=input("enter sub string")
if b in a:
  print(a.find(b))

else:
  print("no")
# Out:
# enter string:poorna
# enter sub stringoor
# 1

# %%
#program that prints reverse of a number with using funcions
def reverse(a):
  rev=0
  while(a!=0):
    key=a%10
    rev=rev*10+key
    a=a//10
  return rev
print(reverse(123))
# Out:
# 321
