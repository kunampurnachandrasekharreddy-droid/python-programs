# %% [markdown]
# <a href="https://colab.research.google.com/github/kunampurnachandrasekharreddy-droid/python-programs/blob/main/week1/program1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("hello")
# Out:
# hello

# %%
#using arthematic operators
x=int(input("enter any intrger:"))
y=int(input("enter any intrger:"))
print(x+y,"is addition")
print(x-y,"is subtraction")
print(x*y,"is multiplication")
print(x/y,"is division")
print(x%y,"is modulus")
print(x**y,"is power")
print(x//y,"is floor division")
# Out:
# enter any intrger:9
# enter any intrger:4
# 13 is addition
# 5 is subtraction
# 36 is multiplication
# 2.25 is division
# 1 is modulus
# 6561 is power
# 2 is floor division

# %%
#comparision operator
x=int(input("enter any intrger:"))
y=int(input("enter any intrger:"))
print(x==y)
print(x!=y)
print(x>y)
print(x<y)
print(x>=y)
print(x<=y)
# Out:
# enter any intrger:5
# enter any intrger:2
# False
# True
# True
# False
# True
# False

# %%
#logical oiperators
x=int(input("enter any intrger:"))
y=int(input("enter any intrger:"))
print(x>y and x<y)
print(x>y or x<y)
print(not(x>y))
# Out:
# enter any intrger:5
# enter any intrger:4
# False
# True
# False

# %%
#bitwise operators
x=int(input("enter any intrger:"))
y=int(input("enter any intrger:"))
print(x>y & x<y)
print(x>y | x<y)
# Out:
# enter any intrger:5
# enter any intrger:3
# True
# False

# %%
#identify operators
x=int(input("enter any intrger:"))
y=int(input("enter any intrger:"))
print(x is y)
print(x is not y)
# Out:
# enter any intrger:5
# enter any intrger:5
# True
# False
